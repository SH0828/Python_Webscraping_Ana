# %%
# reqeusts, bs4 import
import requests
# BeautifulSoup  import
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %% [markdown]
# 바로 아래에 있는코드는 공부와 연습삼아 한겁니다 진짜는 다음 코드에있습니다

# %%
url = 'https://news.daum.net/economy'
print(url)

req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Whale/4.32.315.22 Safari/537.36"
    
}
# requests 의 get() 함수 호출하기 
res=requests.get(url, headers=req_header)
res.encoding = 'utf-8'
print(res.status_code, res.ok)
print(type(res))
print(res)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if res.ok:
    html = res.text
    
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html, "html.parser")
    #print(soup)
    # CSS 선택자
    a_tags = soup.select("li a[href*='v.daum.net/v']") 
    print(len(a_tags))
    print(type(a_tags))
    # <a> 태그 리스트 순회하기    
    

    for a_tag in a_tags:
        if a_tag.text:
            title = a_tag.text.strip() #뉴스제목
            link = a_tag['href']  #뉴스링크
            
            print(f' {title} {link}')
else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.daum.net/economy
# 200 True
# <class 'requests.models.Response'>
# <Response [200]>
# 80
# <class 'bs4.element.ResultSet'>
#  韓 반도체는 깨어날 줄 모르고 [AI 칩 전쟁…한국은 없다?] 세계 인공지능(AI) 칩 산업을 엔비디아가 사실상 장악한 가운데, 국내 기업은 갈 길이 멀다는 지적이 쏟아진다. 리벨리온과 퓨리오사AI 같은 팹리스(Fabless·반도체 설계) 업체가 대만 TSMC 등 파운드리 업체를 통해 AI 반도체 신경망처리장치(NPU)를 제조 중이지만, 빅테크와는 비교 불가다. 특히, 국내 AI 산업은 생태계 전반을 포괄적으로 아우르 매경이코노미 2시간 전 https://v.daum.net/v/20250722210317765
#  소비쿠폰 쓰려다가 '화들짝'…"여기서는 못써요" 응답에 '당황'한 소비자 아시아경제 3시간 전 https://v.daum.net/v/20250722204242273
#  ‘해수부 부산 시대’ 조선·해양플랜트까지 업무 넓혀야 부산일보 3시간 전 https://v.daum.net/v/20250722202007801
#  동영상     [이슈대담] “2040년 석탄화력발전소 폐쇄…신재생 에너지 전환” KBS 3시간 전 https://v.daum.net/v/20250722200357366
#  퇴근하면 시작된다...유통업계 다시 불붙은 '6시 쇼핑' 전쟁 중앙일보 4시간 전 https://v.daum.net/v/20250722185103483
#  “자율주행, 이동약자 지원하는 ‘공공성’에 초점 맞춰야” 한겨레 5시간 전 https://v.daum.net/v/20250722183143976
#  꾸준히 강세 흐름 보이는 메이저 알트코인들 : 코리안 크립토 위클리 [INFCL 리서치] 한국경제 5시간 전 https://v.daum.net/v/20250722181057244
#  세계시장 제패한 K뷰티·푸드…'첨단' 아니라며 R&D지원은 쥐꼬리 한국경제 5시간 전 https://v.daum.net/v/20250722175548581
#  동영상     예금자보호 1억 시대…내 돈 어디에 맡길까? 한국경제TV 6시간 전 https://v.daum.net/v/20250722174746199
#  동영상 가평 캠핑장 참변 가족 수색 사흘째…실종자 수색∙복구 총력전 KBS 12분 전 https://v.daum.net/v/20250722230904761
#  트럼프, '엡스타인에 외설그림 편지' 보도 WSJ 순방 취재 배제 이데일리 21분 전 https://v.daum.net/v/20250722230005601
#  [호우 피해 합천 가회면 가보니] 수마 휩쓸고 간 마을, 쓰레기밭으로 변했다 경남신문 2시간 전 https://v.daum.net/v/20250722214226532
#  동영상 급류 탈출부터 차량 전복까지 안전교육 현장 가보니…[영상] 노컷뉴스 2시간 전 https://v.daum.net/v/20250722213601416
#  동영상 "누가 국가유산에" 청주 상당산성에 의문의 쓰레기 더미 MBC충북 2시간 전 https://v.daum.net/v/20250722205453547
#  [현장르포] 수마가 할퀴고 간 경기도 문화유산… 집중호우에 문화재도 아팠다 경인일보 2시간 전 https://v.daum.net/v/20250722205243512
#  동영상 [밀착카메라] 장마엔 젖어서, 폭염엔 더워서…안전 위험한 '폐지 어르신' JTBC 2시간 전 https://v.daum.net/v/20250722205117470

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://news.daum.net/economy'
print(f'{url}')

    # 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}
    # requests 의 get() 함수 호출하기 
res=requests.get(url,headers=req_header)
res.encoding = 'utf-8'
print(type(res))
print(res.status_code)
if res.ok:
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    li_tags = soup.select("li a[href*='v.daum.net/v']")
    print(len(a_tags))
    print(type(a_tags)) 
    # <a> 태그 리스트 순회하기
    for li_tag in soup.select('ul.list_newsheadline2 li'):
        a_tag = li_tag.find('a')
        link = a_tag['href']	
        
        strong_tag = li_tag.select_one('div.cont_thumb strong.tit_txt')
        title = strong_tag.text
        print(f'{link}') 
        print(f'{title}')

else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.daum.net/economy
# <class 'requests.models.Response'>
# 200
# 80
# <class 'bs4.element.ResultSet'>
# https://v.daum.net/v/20250722210317765
# 韓 반도체는 깨어날 줄 모르고 [AI 칩 전쟁…한국은 없다?]
# https://v.daum.net/v/20250722204242273
# 소비쿠폰 쓰려다가 '화들짝'…"여기서는 못써요" 응답에 '당황'한 소비자
# https://v.daum.net/v/20250722202007801
# ‘해수부 부산 시대’ 조선·해양플랜트까지 업무 넓혀야
# https://v.daum.net/v/20250722200357366
# [이슈대담] “2040년 석탄화력발전소 폐쇄…신재생 에너지 전환”
# https://v.daum.net/v/20250722185103483
# 퇴근하면 시작된다...유통업계 다시 불붙은 '6시 쇼핑' 전쟁
# https://v.daum.net/v/20250722183143976
# “자율주행, 이동약자 지원하는 ‘공공성’에 초점 맞춰야”
# https://v.daum.net/v/20250722181057244
# 꾸준히 강세 흐름 보이는 메이저 알트코인들 : 코리안 크립토 위클리 [INFCL 리서치]
# https://v.daum.net/v/20250722175548581
# 세계시장 제패한 K뷰티·푸드…'첨단' 아니라며 R&D지원은 쥐꼬리
# https://v.daum.net/v/20250722174746199
# 예금자보호 1억 시대…내 돈 어디에 맡길까?
